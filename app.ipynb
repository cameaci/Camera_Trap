# %%
import os
import torch
from PytorchWildlife.models import detection as pw_detection
from PytorchWildlife import utils as pw_utils

# %%
# Setting the device to use for computations ('cuda' indicates GPU)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
if DEVICE == "cuda":
    torch.cuda.set_device(0)
    
# Initializing the MegaDetectorV6 model for image detection
# Valid versions are MDV6-yolov9-c, MDV6-yolov9-e, MDV6-yolov10-c, MDV6-yolov10-e or MDV6-rtdetr-c
detection_model = pw_detection.MegaDetectorV6(device=DEVICE, pretrained=True, version="MDV6-yolov10-e")

# Uncomment the following line to use MegaDetectorV5 instead of MegaDetectorV6
#detection_model = pw_detection.MegaDetectorV5(device=DEVICE, pretrained=True, version="a")
# Out:
# Ultralytics 8.3.70  Python-3.9.21 torch-2.6.0+cpu CPU (13th Gen Intel Core(TM) i7-1365U)
# YOLOv10x summary (fused): 503 layers, 31,589,858 parameters, 0 gradients, 169.8 GFLOPs

# %%
tgt_folder_path = os.path.join(".","demo_data","imgs")
results = detection_model.batch_image_detection(tgt_folder_path, batch_size=16)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0: 640x640 6 persons, 1751.4ms
# 1: 640x640 (no detections), 1751.4ms
# 2: 640x640 2 animals, 1751.4ms
# 3: 640x640 1 animal, 1751.4ms
# 4: 640x640 (no detections), 1751.4ms
# 5: 640x640 (no detections), 1751.4ms
# 6: 640x640 (no detections), 1751.4ms
# 7: 640x640 1 animal, 1751.4ms
# 8: 640x640 1 animal, 1751.4ms
# 9: 640x640 (no detections), 1751.4ms
# 10: 640x640 (no detections), 1751.4ms
# 11: 640x640 1 person, 1751.4ms
# Speed: 6.4ms preprocess, 1751.4ms inference, 0.0ms postprocess per image at shape (12, 3, 640, 640)
# 100%|██████████| 1/1 [00:27<00:00, 27.67s/it]

# %%
pw_utils.save_detection_images(results, "batch_output", overwrite=False)
